# %%
# Plot for metabolite metabolite_plot
metabolite_plot = "Lactate"

# %%
import pandas as pd

# %%
d = pd.io.parsers.read_csv('/Users/mxf793/Data/MoMetab+L#1/ELISA.csv')
d
# Out:
#     Sample                Class         IL-6
# 0      139   M1-Arginine-d0.001   615.367665
# 1       99    M1-Arginine-d0.01   649.103873
# 2       59     M1-Arginine-d0.1   507.911595
# 3       19       M1-Arginine-d1   454.808305
# 4      140   M1-Arginine+d0.001   903.374922
# 5      100    M1-Arginine+d0.01  1075.804429
# 6       60     M1-Arginine+d0.1   939.610108
# 7       20       M1-Arginine+d1   879.634628
# 8      137       M1-BCAA-d0.001   673.468912
# 9       97        M1-BCAA-d0.01   686.588549
# 10      57         M1-BCAA-d0.1   594.126349
# 11      17           M1-BCAA-d1   579.132479
# 12     138       M1-BCAA+d0.001  1034.571286
# 13      98        M1-BCAA+d0.01  1152.023270
# 14      58         M1-BCAA+d0.1  1088.299321
# 15      18           M1-BCAA+d1  1047.690923
# 16     124     M1-Fibro1-d0.001   571.635544
# 17      84      M1-Fibro1-d0.01   481.047578
# 18      44       M1-Fibro1-d0.1   560.390141
# 19       4         M1-Fibro1-d1   561.014886
# 20     125     M1-Fibro1+d0.001   930.863684
# 21      85      M1-Fibro1+d0.01   995.837122
# 22      45       M1-Fibro1+d0.1  1076.429174
# 23       5         M1-Fibro1+d1  1100.794213
# 24     126     M1-Fibro2-d0.001   532.901379
# 25      86      M1-Fibro2-d0.01   546.021015
# 26      46       M1-Fibro2-d0.1   497.915682
# 27       6         M1-Fibro2-d1   573.509777
# 28     121     M1-Fibro2+d0.001  1061.435304
# 29      81      M1-Fibro2+d0.01  1114.538594
# 30      41       M1-Fibro2+d0.1  1143.276845
# 31       1         M1-Fibro2+d1  1137.654144
# 32     127     M1-Fibro3-d0.001   613.493431
# 33      87      M1-Fibro3-d0.01   591.627371
# 34      47       M1-Fibro3-d0.1   574.759267
# 35       7         M1-Fibro3-d1   559.140652
# 36     128     M1-Fibro3+d0.001  1080.802386
# 37      88      M1-Fibro3+d0.01  1118.911806
# 38      48       M1-Fibro3+d0.1  1058.311581
# 39       8         M1-Fibro3+d1  1010.830992
# 40     129      M1-2deox-d0.001   247.393100
# 41      89       M1-2deox-d0.01   213.656892
# 42      49        M1-2deox-d0.1   154.306156
# 43       9          M1-2deox-d1    82.460528
# 44     130      M1-2deox+d0.001   250.516823
# 45      90       M1-2deox+d0.01   204.910468
# 46      50        M1-2deox+d0.1   156.805135
# 47      10          M1-2deox+d1    80.586294
# 48     134    M1-Glucose-d0.001   657.850297
# 49      94     M1-Glucose-d0.01   699.083440
# 50      54      M1-Glucose-d0.1   743.440307
# 51      14        M1-Glucose-d1   780.300237
# 52     135    M1-Glucose+d0.001  1012.705226
# 53      95     M1-Glucose+d0.01  1050.189901
# 54      55      M1-Glucose+d0.1  1052.688880
# 55      15        M1-Glucose+d1  1017.078438
# 56     136  M1-Glutamine-d0.001   674.718401
# 57      96   M1-Glutamine-d0.01   389.834867
# 58      56    M1-Glutamine-d0.1   244.894122
# 59      16      M1-Glutamine-d1    73.714104
#        ...                  ...          ...
#
# [204 rows x 3 columns]

# %%
single = d[ pd.Series([ (metabolite_plot in s or 'RPMI' in s) and '0.001' in s for s in d['Class']])]

single
# Out:
#      Sample              Class         IL-6
# 64      132  M1-Lactate-d0.001  1045.816689
# 68      133  M1-Lactate+d0.001  1248.858681
# 72       14     M1-RPMI-d0.001   487.295024
# 73       15     M1-RPMI-d0.001   446.686625
# 74       16     M1-RPMI-d0.001   531.027145
# 75       17     M1-RPMI-d0.001   551.643717
# 88       31     M1-RPMI+d0.001  1013.329970
# 89       32     M1-RPMI+d0.001   811.537467
# 90       33     M1-RPMI+d0.001  1005.833035
# 164     151  M2-Lactate-d0.001  1121.410785
# 168     152  M2-Lactate+d0.001  1295.714526
# 172      33     M2-RPMI-d0.001   424.195820
# 173      34     M2-RPMI-d0.001   347.352235
# 174      35     M2-RPMI-d0.001   351.100703
# 175      36     M2-RPMI-d0.001   369.218296
# 188      49     M2-RPMI+d0.001  1230.116344
# 189      50     M2-RPMI+d0.001  1093.922023
# 190      51     M2-RPMI+d0.001  1076.429174
# 191      52     M2-RPMI+d0.001  1011.455736
#
# [19 rows x 3 columns]

# %%
single['Mo'] = pd.Series([ s[:2] for s in single['Class']], index=single.index, dtype=str)
single['Condition'] = pd.Series([ 'RPMI' if 'RPMI' in s else metabolite_plot for s in single['Class']], index=single.index, dtype=str)
single
# Out:
#      Sample              Class         IL-6  Mo Condition
# 64      132  M1-Lactate-d0.001  1045.816689  M1   Lactate
# 68      133  M1-Lactate+d0.001  1248.858681  M1   Lactate
# 72       14     M1-RPMI-d0.001   487.295024  M1      RPMI
# 73       15     M1-RPMI-d0.001   446.686625  M1      RPMI
# 74       16     M1-RPMI-d0.001   531.027145  M1      RPMI
# 75       17     M1-RPMI-d0.001   551.643717  M1      RPMI
# 88       31     M1-RPMI+d0.001  1013.329970  M1      RPMI
# 89       32     M1-RPMI+d0.001   811.537467  M1      RPMI
# 90       33     M1-RPMI+d0.001  1005.833035  M1      RPMI
# 164     151  M2-Lactate-d0.001  1121.410785  M2   Lactate
# 168     152  M2-Lactate+d0.001  1295.714526  M2   Lactate
# 172      33     M2-RPMI-d0.001   424.195820  M2      RPMI
# 173      34     M2-RPMI-d0.001   347.352235  M2      RPMI
# 174      35     M2-RPMI-d0.001   351.100703  M2      RPMI
# 175      36     M2-RPMI-d0.001   369.218296  M2      RPMI
# 188      49     M2-RPMI+d0.001  1230.116344  M2      RPMI
# 189      50     M2-RPMI+d0.001  1093.922023  M2      RPMI
# 190      51     M2-RPMI+d0.001  1076.429174  M2      RPMI
# 191      52     M2-RPMI+d0.001  1011.455736  M2      RPMI
#
# [19 rows x 5 columns]

# %%
del single['Sample']
del single['Class']

# %%
#data = lactate.set_index(['Mo','Condition'])

group = single.groupby(['Mo','Condition'])
m = group.mean()
e = group.std()

data = single

# %%
from matplotlib import pyplot as plt
from matplotlib import rcParams
rcParams['font.serif'] = ['Computer Modern Roman', 'Times New Roman']
rcParams['font.family'] = 'serif'

# %%
ax = m.plot(kind='bar', title='Il-6 production by M1 and M2 with 0.001mM %s' % metabolite_plot, yerr=e.values, color='k', ecolor='k')
ax.set_ylabel('Il-6 pg/ml')
ax.set_xlabel('Monocyte subset + Culture conditions')
ax.set_xticklabels( ('M1 + %s' % metabolite_plot, 'M1 + RPMI', 'M2 + %s' % metabolite_plot, 'M2 + RPMI'), rotation=0 )
ax.get_legend().remove()
ax.grid(False)

fig = ax.get_figure()
fig.set_size_inches((6,6))
fig.savefig('/Users/mxf793/Data/MoMetab+L#1/m1m2-%s-il6.png' % metabolite_plot, dpi=200)

# %%
from scipy.stats import ttest_ind

# %%
m1r = data[(data["Mo"]=="M1") & (data["Condition"]=="RPMI") ]["IL-6"]
m1l = data[(data["Mo"]=="M1") & (data["Condition"]==metabolite_plot) ]["IL-6"]

r = ttest_ind(m1r.values, m1l.values)
print("M1 RPMI vs %s t=%.2f, p=%.2f" % (metabolite_plot, r[0], r[1] ) )

m2r = data[(data["Mo"]=="M2") & (data["Condition"]=="RPMI") ]["IL-6"]
m2l = data[(data["Mo"]=="M2") & (data["Condition"]==metabolite_plot) ]["IL-6"]

r = ttest_ind(m2r.values, m2l.values)
print("M2 RPMI vs %s t=%.2f, p=%.2f" % (metabolite_plot, r[0], r[1] ) )
# Out:
# M1 RPMI vs Lactate t=-2.42, p=0.05
# M2 RPMI vs Lactate t=-1.60, p=0.15

# %% [markdown]
# # ggplot (Python)
#
# The below repeats the graph generation as far as possible using Python ggplot

# %%
m['Moc'] = pd.Series(["%s + %s" % (x1,x2) for x1,x2 in m.index.values],dtype=str,index=m.index)
m
# Out:
#                      IL-6  Mo-Condition           Moc
# Mo Condition
# M1 Lactate    1147.337685  M1 + Lactate  M1 + Lactate
#    RPMI        692.478998     M1 + RPMI     M1 + RPMI
# M2 Lactate    1208.562655  M2 + Lactate  M2 + Lactate
#    RPMI        737.973791     M2 + RPMI     M2 + RPMI
#
# [4 rows x 3 columns]

# %%
from ggplot import *

p = ggplot(aes(x='factor(Moc)', y='IL-6', width=0.7), data=m)
p + \
geom_bar(stat='identity') + \
ggtitle('Il-6 production by M1 and M2 with 0.001mM %s' % metabolite_plot) + labs('Monocyte subset + Culture conditions', "Il-6 pg/ml")
# geom_errorbar(aes(ymax=e), width=.1, position=m)
# Out:
# <ggplot: (289520077)>
